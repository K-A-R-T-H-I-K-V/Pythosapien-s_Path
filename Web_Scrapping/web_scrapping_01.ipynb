# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq # automatic url opening
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone+11" # base address + query

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone+11'

# %%
urlclient = uReq(flipkart_url)
urlclient

# %%
flipkart_page = urlclient.read() # On opening URL -> right click -> view page source -> html dump

# %%
flipkart_html = bs(flipkart_page, 'html.parser') # Making the data more human readable

# %%
'https://www.flipkart.com'+'/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=84389768-b0c0-4247-95ce-020c21432fa8.MOBFWQ6B7KKRXDDS.SEARCH&ppt=None&ppn=None&ssid=fmfcjvkdsw0000001723213181142&qH=f6cdfdaa9f3c23f3'
# Out:
# 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=84389768-b0c0-4247-95ce-020c21432fa8.MOBFWQ6B7KKRXDDS.SEARCH&ppt=None&ppn=None&ssid=fmfcjvkdsw0000001723213181142&qH=f6cdfdaa9f3c23f3'

# %%
bigbox = flipkart_html.findAll("div", {"class":"cPHDOP col-12-12"}) #find() finds only 1 while findAll() finds all

# %%
len(bigbox)
# Out:
# 30

# %%
# productlink = 'https://www.flipkart.com' + bigbox[4].div.div.div.a['href']
productlink = 'https://www.amazon.in' + '/Apple-iPhone-13-128GB-Midnight/dp/B09G9HD6PD/ref=sr_1_1?adgrpid=1326012633296332&dib=eyJ2IjoiMSJ9.8h9A_YSPiLCsRbGj7EQ9tvZB2sa42jMv0Jf4H329V3p2VR3DQ-2ZtqddwY7jWXEmwzLwIXNKpQvXIgVnYAI8A_aUC4c-ZReyMhv79TN9Ov9_yWWiJKfO9JYZjFsilLJrXmGfyPFAXXhWzCsO3qi0JdWOcXXioIESxPwcTPHe6BONjAUIRhbKdnIoKrXwNG3L-GPLgHZ72cOYsXQ485McsZmwRQfHQRuU8eApTt15Iew.Y-fA6ggiW0TveLJrZ-QB-ZZ1MRwueOv5aFA8D3lNscE&dib_tag=se&hvadid=82876047573269&hvbmt=be&hvdev=c&hvlocphy=116072&hvnetw=o&hvqmt=e&hvtargid=kwd-82876682283444%3Aloc-90&hydadcr=24570_1955347&keywords=iphone+amazon&msclkid=13347483084618fbb992123b38f21e0c&qid=1723347131&sr=8-1'

# %%
product_req = requests.get(productlink)
product_req
# Out:
# <Response [200]>

# %%
print(productlink)
# Out:
# https://www.amazon.in/Apple-iPhone-13-128GB-Midnight/dp/B09G9HD6PD/ref=sr_1_1?adgrpid=1326012633296332&dib=eyJ2IjoiMSJ9.8h9A_YSPiLCsRbGj7EQ9tvZB2sa42jMv0Jf4H329V3p2VR3DQ-2ZtqddwY7jWXEmwzLwIXNKpQvXIgVnYAI8A_aUC4c-ZReyMhv79TN9Ov9_yWWiJKfO9JYZjFsilLJrXmGfyPFAXXhWzCsO3qi0JdWOcXXioIESxPwcTPHe6BONjAUIRhbKdnIoKrXwNG3L-GPLgHZ72cOYsXQ485McsZmwRQfHQRuU8eApTt15Iew.Y-fA6ggiW0TveLJrZ-QB-ZZ1MRwueOv5aFA8D3lNscE&dib_tag=se&hvadid=82876047573269&hvbmt=be&hvdev=c&hvlocphy=116072&hvnetw=o&hvqmt=e&hvtargid=kwd-82876682283444%3Aloc-90&hydadcr=24570_1955347&keywords=iphone+amazon&msclkid=13347483084618fbb992123b38f21e0c&qid=1723347131&sr=8-1

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
product_html.find_all()
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open-
# ...

# %%
#if product_req.status_code == 500 :
#    print("Internal server error")
# Out:
# Internal server error

# %%
del bigbox[0:2]

# %%
for i in bigbox:
    print('https://www.flipkart.com' + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSULUZ0N&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=a83e6eb3-b519-4fdb-9d3e-7653f427430d.MOBFWQ6B7KKRXDDS.SEARCH&ppt=None&ppn=None&ssid=n0zw7a0h2o0000001723270779211&qH=f6cdfdaa9f3c23f3
# https://www.flipkart.com/apple-iphone-11-white-64-gb-includes-earpods-power-adapter/p/itm2644c3764fc54?pid=MOBFKCTSHAWGGFHM&lid=LSTMOBFKCTSHAWGGFHMNDVENT&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=a83e6eb3-b519-4fdb-9d3e-7653f427430d.MOBFKCTSHAWGGFHM.SEARCH&ppt=None&ppn=None&ssid=n0zw7a0h2o0000001723270779211&qH=f6cdfdaa9f3c23f3
# ...
