# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b7dd5164-ad91-4f4d-9e12-2f8bce81ba39">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p = figure(title = 'Flowers Analysis')
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="ebfe7c7c-48a1-4126-896d-6d1195eb1aca" data-root-id="p1045" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p = figure(title = 'Flowers Analysis')
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="fb774caa-16d6-46ed-90fd-66f3a0c0e921" data-root-id="p1125" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

output_file('line.html')

p = figure(title = 'Line Plot')
p.xaxis.axis_label = 'x-axis'
p.yaxis.axis_label = 'y-axis'
p.line([2, 3, 4, 5, 6], [4, 5, 6, 7, 8], line_color = 'red')
show(p)
# Out:
#   <div id="cce2eff9-86b7-4e41-8883-35136ada329e" data-root-id="p1252" style="display: contents;"></div>

# %%
output_file('line.html')

p = figure(title = 'Line Plot')
p.xaxis.axis_label = 'x-axis'
p.yaxis.axis_label = 'y-axis'
p.scatter([2, 3, 4, 5, 6], [4, 5, 6, 7, 8], fill_color = 'cyan', legend_label = 'Cyan Points', size = 20)
show(p)
# Out:
#   <div id="c3cffc1a-ac48-4b23-ab68-76e351f7473a" data-root-id="p1340" style="display: contents;"></div>
